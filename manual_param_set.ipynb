# %%
import socketio
import numpy as np
import time

# %%
ip_var = "192.168.1.122:5000"
sio = socketio.Client()
i = 0
while True:
    try:
        i += 1
        sio.connect(f"ws://{ip_var}")
        break
    except socketio.exceptions.ConnectionError:
        if i > 5:
            print("Exceeded maximum number of retries. Exiting...")
            exit()
        print("Connection failed. Retrying...")
        time.sleep(1)

# %%
# DELAYED BT
parameters = {
    "hip_delay_idx": 20,
    "h_flex_torque_scale": 0.2,
    "h_ext_torque_scale": 0.2,
    "h_flex_ang_scale": 0.0,
    "h_ext_ang_scale": 0.0,
    "h_flex_power_scale": 0.0,
    "h_ext_power_scale": 0.0,
    "h_flex_grf_scale": 0.0,
    "h_ext_grf_scale": 0.0,
    "knee_delay_idx": 0,
    "k_ext_torque_scale": 0.15,
    "k_flex_torque_scale": 0.15,
    "k_ext_ang_scale": 0.0,
    "k_flex_ang_scale": 0.0,
    "k_ext_power_scale": 0.0,
    "k_flex_power_scale": 0.0,
    "k_ext_grf_scale": 0.0,
    "k_flex_grf_scale": 0.0
}
sio.emit("update_inputs", parameters)

# %% [markdown]
# ## MT08 Params

# %%
# INCLINE OPTIMAL - MT08
parameters = {
    "hip_delay_idx": 0,
    "h_flex_torque_scale": 0.13157731071496243,
    "h_ext_torque_scale": 0.13157731071496243,
    "h_flex_ang_scale": 0.0,
    "h_ext_ang_scale": 0.0,
    "h_flex_power_scale": 0.012678187842943256,
    "h_ext_power_scale": -0.10665492055969383,
    "h_flex_grf_scale": 0.0,
    "h_ext_grf_scale": 0.0,
    "knee_delay_idx": 0,
    "k_ext_torque_scale": 0.1648025044444527,
    "k_flex_torque_scale": 0.16193659543116978,
    "k_ext_ang_scale": 0.0,
    "k_flex_ang_scale": 0.0,
    "k_ext_power_scale": 0.12202496796036304,
    "k_flex_power_scale": -0.08961697000366516,
    "k_ext_grf_scale": 0.0,
    "k_flex_grf_scale": 0.0
}
sio.emit("update_inputs", parameters)

# %%
# STEP OPTIMAL - MT08
parameters = {
    "hip_delay_idx": 0,
    "h_flex_torque_scale": 0.010521508120769843,
    "h_ext_torque_scale": 0.010521508120769843,
    "h_flex_ang_scale": 0.0,
    "h_ext_ang_scale": 0.0,
    "h_flex_power_scale": 0.09913066572698524,
    "h_ext_power_scale": -0.13859888727156622,
    "h_flex_grf_scale": 0.0,
    "h_ext_grf_scale": 0.0,
    "knee_delay_idx": 0,
    "k_ext_torque_scale": 0.15400090894434854,
    "k_flex_torque_scale": 0.09306609931615227,
    "k_ext_ang_scale": 0.0,
    "k_flex_ang_scale": 0.0,
    "k_ext_power_scale": 0.10641230691228229,
    "k_flex_power_scale": -0.05216759920388299,
    "k_ext_grf_scale": 0.0,
    "k_flex_grf_scale": 0.0
}
sio.emit("update_inputs", parameters)

# %%
# SQUAT OPTIMAL - MT08
parameters = {
    "hip_delay_idx": 0,
    "h_flex_torque_scale": 0.1811506169479078,
    "h_ext_torque_scale": 0.1811506169479078,
    "h_flex_ang_scale": 0.0,
    "h_ext_ang_scale": 0.0,
    "h_flex_power_scale": 0.17433127321400754,
    "h_ext_power_scale": -0.2192114799199047,
    "h_flex_grf_scale": 0.0,
    "h_ext_grf_scale": 0.0,
    "knee_delay_idx": 0,
    "k_ext_torque_scale": 0.19891051164543444,
    "k_flex_torque_scale": 0.04389412517867451,
    "k_ext_ang_scale": 0.0,
    "k_flex_ang_scale": 0.0,
    "k_ext_power_scale": 0.06504569568922457,
    "k_flex_power_scale": -0.0644637954434503,
    "k_ext_grf_scale": 0.0,
    "k_flex_grf_scale": 0.0
}
sio.emit("update_inputs", parameters)

# %% [markdown]
# ## MT07 Params

# %%
# STEP OPTIMAL - MT07
parameters = {
    "hip_delay_idx": 0,
    "h_flex_torque_scale": 0.08948247480419108,
    "h_ext_torque_scale": 0.08948247480419108,
    "h_flex_ang_scale": 0.0,
    "h_ext_ang_scale": 0.0,
    "h_flex_power_scale": 0.10079156836579886,
    "h_ext_power_scale": -0.17316253363392575,
    "h_flex_grf_scale": 0.0,
    "h_ext_grf_scale": 0.0,
    "knee_delay_idx": 0,
    "k_ext_torque_scale": 0.07291608316291848,
    "k_flex_torque_scale": 0.07931362984372511,
    "k_ext_ang_scale": 0.0,
    "k_flex_ang_scale": 0.0,
    "k_ext_power_scale": 0.11385665566572327,
    "k_flex_power_scale": -0.08703140434403586,
    "k_ext_grf_scale": 0.0,
    "k_flex_grf_scale": 0.0
}
sio.emit("update_inputs", parameters)

# %%
# SQUAT OPTIMAL - MT07
parameters = {
    "hip_delay_idx": 0,
    "h_flex_torque_scale": 0.2687442646735624,
    "h_ext_torque_scale": 0.2687442646735624,
    "h_flex_ang_scale": 0.0,
    "h_ext_ang_scale": 0.0,
    "h_flex_power_scale": 0.003649094108780925,
    "h_ext_power_scale": -0.10615802118213413,
    "h_flex_grf_scale": 0.0,
    "h_ext_grf_scale": 0.0,
    "knee_delay_idx": 0,
    "k_ext_torque_scale": 0.07017836978360735,
    "k_flex_torque_scale": 0.07153691526902838,
    "k_ext_ang_scale": 0.0,
    "k_flex_ang_scale": 0.0,
    "k_ext_power_scale": 0.14344326243033229,
    "k_flex_power_scale": -0.136173827912039,
    "k_ext_grf_scale": 0.0,
    "k_flex_grf_scale": 0.0
}
sio.emit("update_inputs", parameters)

# %%
# INCLINE OPTIMAL - MT07
parameters = {
    "hip_delay_idx": 0,
    "h_flex_torque_scale": 0.18537501764894407,
    "h_ext_torque_scale": 0.18537501764894407,
    "h_flex_ang_scale": 0.0,
    "h_ext_ang_scale": 0.0,
    "h_flex_power_scale": 0.17143692966760754,
    "h_ext_power_scale": -0.19633549696689045,
    "h_flex_grf_scale": 0.0,
    "h_ext_grf_scale": 0.0,
    "knee_delay_idx": 0,
    "k_ext_torque_scale": 0.19972316952916583,
    "k_flex_torque_scale": 0.024628229052417714,
    "k_ext_ang_scale": 0.0,
    "k_flex_ang_scale": 0.0,
    "k_ext_power_scale": 0.07866321152050787,
    "k_flex_power_scale": -0.05202699440586453,
    "k_ext_grf_scale": 0.0,
    "k_flex_grf_scale": 0.0
}
sio.emit("update_inputs", parameters)

# %% [markdown]
# ## MT06 Params

# %%
# SQUAT OPTIMAL - MT06
parameters = {
    "hip_delay_idx": 0,
    "h_flex_torque_scale": 0.18180282713377677,
    "h_ext_torque_scale": 0.18180282713377677,
    "h_flex_ang_scale": 0.0,
    "h_ext_ang_scale": 0.0,
    "h_flex_power_scale": 0.09204497281537403,
    "h_ext_power_scale": -0.17776891850753038,
    "h_flex_grf_scale": 0.0,
    "h_ext_grf_scale": 0.0,
    "knee_delay_idx": 0,
    "k_ext_torque_scale": 0.12977168843603537,
    "k_flex_torque_scale": 0.08059063921823574,
    "k_ext_ang_scale": 0.0,
    "k_flex_ang_scale": 0.0,
    "k_ext_power_scale": 0.11371082221363356,
    "k_flex_power_scale": -0.03680974492739823,
    "k_ext_grf_scale": 0.0,
    "k_flex_grf_scale": 0.0
}
sio.emit("update_inputs", parameters)

# %%
# STEP OPTIMAL - MT06
parameters = {
    "hip_delay_idx": 0,
    "h_flex_torque_scale": 0.17502026424233333,
    "h_ext_torque_scale": 0.17502026424233333,
    "h_flex_ang_scale": 0.0,
    "h_ext_ang_scale": 0.0,
    "h_flex_power_scale": 0.10745907280319676,
    "h_ext_power_scale": -0.20392893600051948,
    "h_flex_grf_scale": 0.0,
    "h_ext_grf_scale": 0.0,
    "knee_delay_idx": 0,
    "k_ext_torque_scale": 0.1445541329925062,
    "k_flex_torque_scale": 0.04106471241602566,
    "k_ext_ang_scale": 0.0,
    "k_flex_ang_scale": 0.0,
    "k_ext_power_scale": 0.07855808065466334,
    "k_flex_power_scale": -0.09673671226026909,
    "k_ext_grf_scale": 0.0,
    "k_flex_grf_scale": 0.0
}
sio.emit("update_inputs", parameters)

# %%
# INCLINE OPTIMAL - MT06
parameters = {
    "hip_delay_idx": 0,
    "h_flex_torque_scale": 0.16434622499089296,
    "h_ext_torque_scale": 0.16434622499089296,
    "h_flex_ang_scale": 0.0,
    "h_ext_ang_scale": 0.0,
    "h_flex_power_scale": 0.12950539876750225,
    "h_ext_power_scale": -0.22209340080284581,
    "h_flex_grf_scale": 0.0,
    "h_ext_grf_scale": 0.0,
    "knee_delay_idx": 0,
    "k_ext_torque_scale": 0.12714373632812015,
    "k_flex_torque_scale": 0.17484367235928067,
    "k_ext_ang_scale": 0.0,
    "k_flex_ang_scale": 0.0,
    "k_ext_power_scale": 0.08964890984277805,
    "k_flex_power_scale": -0.07689192377840692,
    "k_ext_grf_scale": 0.0,
    "k_flex_grf_scale": 0.0
}
sio.emit("update_inputs", parameters)

# %% [markdown]
# ## MT04 Params

# %%
# INCLINE OPTIMAL
parameters = {
    "hip_delay_idx": 0,
    "h_flex_torque_scale": 0.1840566992888399,
    "h_ext_torque_scale": 0.1840566992888399,
    "h_flex_ang_scale": 0.0,
    "h_ext_ang_scale": 0.0,
    "h_flex_power_scale": 0.16558812266967293,
    "h_ext_power_scale": -0.16328323037549702,
    "h_flex_grf_scale": 0.0,
    "h_ext_grf_scale": 0.0,
    "knee_delay_idx": 0,
    "k_ext_torque_scale": 0.07418697072705775,
    "k_flex_torque_scale": 0.19345113437222142,
    "k_ext_ang_scale": 0.0,
    "k_flex_ang_scale": 0.0,
    "k_ext_power_scale": 0.08530156964468308,
    "k_flex_power_scale": -0.07080001893686871,
    "k_ext_grf_scale": 0.0,
    "k_flex_grf_scale": 0.0
}
sio.emit("update_inputs", parameters)

# %%
# STEP OPTIMAL
parameters = {
    "hip_delay_idx": 0,
    "h_flex_torque_scale": 0.267263382493691,
    "h_ext_torque_scale": 0.267263382493691,
    "h_flex_ang_scale": 0.0,
    "h_ext_ang_scale": 0.0,
    "h_flex_power_scale": 0.2042075175838011,
    "h_ext_power_scale": -0.19000678532104412,
    "h_flex_grf_scale": 0.0,
    "h_ext_grf_scale": 0.0,
    "knee_delay_idx": 0,
    "k_ext_torque_scale": 0.16823521109567335,
    "k_flex_torque_scale": 0.04458740177291938,
    "k_ext_ang_scale": 0.0,
    "k_flex_ang_scale": 0.0,
    "k_ext_power_scale": 0.10056265474336891,
    "k_flex_power_scale": -0.023682258901211534,
    "k_ext_grf_scale": 0.0,
    "k_flex_grf_scale": 0.0
}
sio.emit("update_inputs", parameters)

# %%
# SQUAT OPTIMAL
parameters = {
    "hip_delay_idx": 0,
    "h_flex_torque_scale": 0.1849778856729313,
    "h_ext_torque_scale": 0.1849778856729313,
    "h_flex_ang_scale": 0.0,
    "h_ext_ang_scale": 0.0,
    "h_flex_power_scale": 0.07525379370580101,
    "h_ext_power_scale": -0.23937448431680497,
    "h_flex_grf_scale": 0.0,
    "h_ext_grf_scale": 0.0,
    "knee_delay_idx": 0,
    "k_ext_torque_scale": 0.1901526505845596,
    "k_flex_torque_scale": 0.08627325094771321,
    "k_ext_ang_scale": 0.0,
    "k_flex_ang_scale": 0.0,
    "k_ext_power_scale": 0.1361409728245866,
    "k_flex_power_scale": -0.04360523896584852,
    "k_ext_grf_scale": 0.0,
    "k_flex_grf_scale": 0.0
}
sio.emit("update_inputs", parameters)

# %% [markdown]
# ## MT03 Params

# %%
# SQUAT OPTIMAL
parameters = {
    "hip_delay_idx": 0,
    "h_flex_torque_scale": 0.00032633103630628623,
    "h_ext_torque_scale": 0.00032633103630628623,
    "h_flex_ang_scale": 0.0,
    "h_ext_ang_scale": 0.0,
    "h_flex_power_scale": 0.09399005576208061,
    "h_ext_power_scale": -0.22812067622392562,
    "h_flex_grf_scale": 0.0,
    "h_ext_grf_scale": 0.0,
    "knee_delay_idx": 0,
    "k_ext_torque_scale": 0.0945881066425496,
    "k_flex_torque_scale": 0.004417008215472869,
    "k_ext_ang_scale": 0.0,
    "k_flex_ang_scale": 0.0,
    "k_ext_power_scale": 0.10267800409993827,
    "k_flex_power_scale": -0.042751358398918124,
    "k_ext_grf_scale": 0.0,
    "k_flex_grf_scale": 0.0
}
sio.emit("update_inputs", parameters)

# %%
# STEP OPTIMAL
parameters = {
    "hip_delay_idx": 0,
    "h_flex_torque_scale": 0.09612389377985894,
    "h_ext_torque_scale": 0.09612389377985894,
    "h_flex_ang_scale": 0.0,
    "h_ext_ang_scale": 0.0,
    "h_flex_power_scale": 0.09231353090589105,
    "h_ext_power_scale": -0.160546767542955,
    "h_flex_grf_scale": 0.0,
    "h_ext_grf_scale": 0.0,
    "knee_delay_idx": 0,
    "k_ext_torque_scale": 0.1019579160301789,
    "k_flex_torque_scale": 0.10886781079260358,
    "k_ext_ang_scale": 0.0,
    "k_flex_ang_scale": 0.0,
    "k_ext_power_scale": 0.04554161005012942,
    "k_flex_power_scale": -0.06785754477299685,
    "k_ext_grf_scale": 0.0,
    "k_flex_grf_scale": 0.0
}
sio.emit("update_inputs", parameters)

# %%
# INCLINE OPTIMAL
parameters = {
    "hip_delay_idx": 0,
    "h_flex_torque_scale": 0.20195211056851617,
    "h_ext_torque_scale": 0.20195211056851617,
    "h_flex_ang_scale": 0.0,
    "h_ext_ang_scale": 0.0,
    "h_flex_power_scale": 0.13267558588720407,
    "h_ext_power_scale": -0.239856256660001,
    "h_flex_grf_scale": 0.0,
    "h_ext_grf_scale": 0.0,
    "knee_delay_idx": 0,
    "k_ext_torque_scale": 0.10169169033763502,
    "k_flex_torque_scale": 0.03028826416940333,
    "k_ext_ang_scale": 0.0,
    "k_flex_ang_scale": 0.0,
    "k_ext_power_scale": 0.0622553368087889,
    "k_flex_power_scale": -0.04683576989413163,
    "k_ext_grf_scale": 0.0,
    "k_flex_grf_scale": 0.0
}
sio.emit("update_inputs", parameters)
# Out:
# packet queue is empty, aborting
# packet queue is empty, aborting

# %%
# # WALK OPTIMAL
# parameters = {
#     "hip_delay_idx": 0,
#     "h_flex_torque_scale": 0.18344184347360867,
#     "h_ext_torque_scale": 0.18344184347360867,
#     "h_flex_ang_scale": 0.0,
#     "h_ext_ang_scale": 0.0,
#     "h_flex_power_scale": 0.03369944386978089,
#     "h_ext_power_scale": -0.04716686049813586,
#     "h_flex_grf_scale": 0.0,
#     "h_ext_grf_scale": 0.0,
#     "knee_delay_idx": 0,
#     "k_ext_torque_scale": 0.06553068776211453,
#     "k_flex_torque_scale": 0.12446984009497358,
#     "k_ext_ang_scale": 0.0,
#     "k_flex_ang_scale": 0.0,
#     "k_ext_power_scale": 0.000017794880153095384,
#     "k_flex_power_scale": -0.021685316271890062,
#     "k_ext_grf_scale": 0.0,
#     "k_flex_grf_scale": 0.0
# }
# sio.emit("update_inputs", parameters)
